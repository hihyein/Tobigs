# %%
# -*- coding:utf-8 -*-

from bs4 import BeautifulSoup
import urllib.request
import requests
import re

# %%
# url 가져오는 함수
def getting_url():
    out = open("조선일보_사설URL.txt", 'w')

    # 3월 4일부터 5월 7일까지 2달간 아티클 주소 뽑기.
    for i in range(44):
        url = 'http://news.chosun.com/svc/list_in/list.html?catid=617&pn=' + str(i + 1)
        source_code = requests.get(url)
        text_f = source_code.text
        soup = BeautifulSoup(text_f, 'lxml')
        cnt = 0;
        for title_list in soup.find_all("dd", {"class": "desc"}):

            title_list2 = title_list.find_next("a")
            href = title_list2.get("href")
            print(href, file=out)
    out.close()

# %%
# 받은 url로 크롤링하는 함수

def get_text(URL):
    source_code_from_URL = urllib.request.urlopen(URL)
    soup = BeautifulSoup(source_code_from_URL, 'lxml', from_encoding='utf-8')
    text_title = soup.find_all("h1",id = 'news_title_text_id')
    text_title_clean = re.search('\] (.*?)\</', str(text_title))
    text_title = str(text_title_clean.group(1))
    print(text_title)
    text = soup.find_all("div", {"class","par"})
    text = text_title + "\n" + str(text)+"\n\n"
    return str(text)

    # text = ''
    # for item in soup.find_all('div', id='article_body'):
    #     text = text + str(item.find_all(text=True))
    #
    # return text

# %%
# 클리닝 함수
def clean_text(text):
    cleaner1 = re.compile('<.*?>')
    remove_tag = re.sub(cleaner1, '', text)
    cleaner2 = re.compile('[.*?]')
    remove_tag2 = re.sub(cleaner2, '', remove_tag)
    remove_num = re.sub('\d', '', remove_tag2)
    remove_sasul = re.sub('사설', '', remove_num)
    cleaned_text1 = re.sub('[a-zA-Z]', '', remove_sasul)
    cleaned_text2 = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', cleaned_text1)
    return cleaned_text2

# %%
# 메인 함수
def main():
    # url 가져오기
    getting_url()

    open_url = open("조선일보_사설URL.txt", "r")
    open_output_file = open("조선일보 사설_text.txt", 'w', encoding='utf8')

    # url에서 \n 없애기
    url = []
    lines = open_url.readlines()
    for line in lines:
        line = line[:-1]
        url.append(line)

    for url_i in url:
        print(url.index(url_i)+1, "번째 기사")

        # 제목 쓰기
        open_output_file.write(str(url.index(url_i)+1) + "번째 기사\n")

        # 받은 url로 크롤링하는 함수
        result_text = get_text(url_i)

        # 클리닝 함수
        result_text = clean_text(result_text)

        # 클리닝 된 것 파일에 쓰기
        open_output_file.write(result_text)

    open_output_file.close()


if __name__ == '__main__':
    main()
# Out:
# 1 번째 기사
# 한국대사관이 시위대에 포위되면 어떻겠나
# 2 번째 기사
# 6·25 날에 생각하는 '콜라 훔치던 연평해전 부상 군인'
# 3 번째 기사
# 2020년 우리 최저임금이 일본보다 높아진다는데
# 4 번째 기사
# 사드 상황 모른다는 것 더 이상 내세울 일 아니다
# 5 번째 기사
# 청와대 앞길 연다니 민노총 농성 천막부터 섰다
# 6 번째 기사
# 교사 성과급도 폐지 요구, 세금 내는 국민만 봉
# 7 번째 기사
# 韓 '원전 중단'에 쾌재 부르는 日 산업계
# 8 번째 기사
# 主流 무조건 배제한 코드 인사가 난국 자초
# 9 번째 기사
# 또 통신비 강제 인하, 정권 초 팔 비틀기 굳어지나
# 10 번째 기사
# "北 뻥치고 있다"는 文 대통령 인식
# 11 번째 기사
# '주한 미군 철수' 교육부총리, '방산 10억 자문료' 국방장관
# 12 번째 기사
# 특권 집단 민노총의 '기득권과의 전쟁'
# 13 번째 기사
# 美·北은 위험, 韓·美는 불안 속 열리는 文·트럼프 회담
# 14 번째 기사
# 웜비어 사망, 文 정부 北 인권 인식 바뀌어야
# 15 번째 기사
# "일자리 기금 내겠다" 민노총, 알고 보니 '쇼'
# 16 번째 기사
# 全국민 수십년 영향 '원전 중단', 5년 대통령 아닌 국민이 정해야
# 17 번째 기사
# 상습 사고 안보팀 이대로 괜찮은가
# 18 번째 기사
# 이제 사법부에 '판사 노조' 만들겠다는 것인가
# 19 번째 기사
# 北 추가 도발만 안 해도 韓美훈련 축소하겠다니
# 20 번째 기사
# 대통령 對 야당, 너무 빨리 대결로 간다
# 21 번째 기사
# 랜섬웨어 공격 대비책 세워야
# 22 번째 기사
# 안경환 첫 낙마, 김상곤·조대엽도 짐 되지 말고 물러나길
# 23 번째 기사
# 대통령이 국민 앞에 사과해야 할 때 아닌가
# 24 번째 기사
# 산타클로스 정부, 선물 값은 누가 내나
# 25 번째 기사
# 지금 '독선' 경계 않으면 前 정권 전철 밟는다
# 26 번째 기사
# 김상곤 후보자의 해도 너무한 '내로남불'
# 27 번째 기사
# 5년 정권이 수십년 역사 학교들을 멋대로 폐지하나
# 28 번째 기사
# 대통령 人事 독주 멈추고, 野 정부 출범 도우라
# 29 번째 기사
# 文 정부 '교사도 공기업 직원도 편하게 해준다'는데
# 30 번째 기사
# 권세 부리는 민노총, 제 세상 만났다는 건가
# 31 번째 기사
# 김상조 임명 강행, 親文 일색 '시민단체 정부'
# 32 번째 기사
# '직업적 도덕성'과 김상곤, 송영무, 안경환
# 33 번째 기사
# 성주 사드 포대 상공 휘젓고 간 北 무인기
# 34 번째 기사
# 성주와 의정부에서 벌어진 어이없는 장면들
# 35 번째 기사
# 장관 발표 때마다 나오는 '내로남불'
# 36 번째 기사
# 임시직 늘리는 일자리 추경, 일회용 선심은 안 된다
# 37 번째 기사
# 장관은 선거 공신, 차관은 코드 인사
# 38 번째 기사
# 宋 국방 후보도 軍事 억지력을 줄타기 수단으로 보나
# 39 번째 기사
# 대통령 첫 국회 연설, 인사 난맥 푸는 기회로
# 40 번째 기사
# 심상찮은 미국 朝野 분위기 걱정스럽다
# 41 번째 기사
# 김동연 경제팀, '정치' 아닌 '경제'만 보면 성공할 것
# 42 번째 기사
# 與 KBS·MBC 장악 시도, 前 정권과 뭐가 다른가
# 43 번째 기사
# '사드 배치 긴급한 일 아니다'는 靑 인식 심각하다
# 44 번째 기사
# 與에서 나온 '文 대통령 한 달'에 대한 걱정
# 45 번째 기사
# 중소기업들 애로 호소에 돌아온 "실망"이란 대답
# 46 번째 기사
# 방미 文 대통령, 기업이란 국가 자산 활용하길
# 47 번째 기사
# 답답하고 한심한 康 후보자 청문회 問答
# 48 번째 기사
# 국정위에서 너무 자주 들리는 호통 소리
# 49 번째 기사
# 文대통령 "애국에 보수도 진보도 없다"
# 50 번째 기사
# 靑, 법령·상황 제대로 알고 사드 환경평가 지시한 건가
# 51 번째 기사
# 北은 도발하는데 軍을 죄인 만들면 누가 得 보나
# 52 번째 기사
# 뒤늦은 사드 환경평가, 절차 준수인가 훼방인가
# 53 번째 기사
# 외교·안보 진용 난맥, 韓美 정상회담 문제없나
# 54 번째 기사
# 한 달에 일자리 18만개씩 생기는 미국의 교훈
# 55 번째 기사
# 국제사회는 대북 압박 강화, 우리는 남북 접촉 봇물
# 56 번째 기사
# 정부가 최대 고용주가 되는 나라
# 57 번째 기사
# AI 피해 그렇게 겪고도 집단 폐사 신고 또 안 했다니
# 58 번째 기사
# 우려되는 국가안보실 능력
# 59 번째 기사
# 野 '김상조 반대' 충분히 납득되지만
# 60 번째 기사
# 최저時給 3년 새 54% 인상, 중소기업계에 물어는 봤나
# 61 번째 기사
# 결국 나온 "한국이 원치 않으면 사드 빼겠다"
# 62 번째 기사
# 석연치 않은 청와대 수석 내정 취소
# 63 번째 기사
# 최저임금 1만원, 영세·중소기업 충격은 어떡할 건가
# 64 번째 기사
# 한·미 정상회담 코앞에 대통령이 사드 논란 전면 나서면
# 65 번째 기사
# 테러방지법 192시간 희롱 민주, 與 되니 어떤가
# 66 번째 기사
# 쿠팡의 善意가 가져온 결말
# 67 번째 기사
# 文 대통령 뜬금없는 "사드 포대 충격적" 이유가 뭔가
# 68 번째 기사
# 金 공정위장, 康 외교 문제 난감하다
# 69 번째 기사
# 세월호 천막은 광화문 무기한 점거하나
# 70 번째 기사
# 文 대통령 '우린 다르다'는 생각부터 지우길
# 71 번째 기사
# 對北 정보 역량 강화가 국정원 개혁이다
# 72 번째 기사
# '원전 폐기' 주장하려면 에너지 代案부터 내놓아야
# 73 번째 기사
# 文 대통령이 '총리 인준 대치' 풀어야
# 74 번째 기사
# 비정규직 95%가 中企인데 "재벌 반성하라"니
# 75 번째 기사
# 벌써 어수선한 중3 교실
# 76 번째 기사
# 비정규직 고용 350만 중소기업이 전부 반성해야 하나
# 77 번째 기사
# 靑 위장전입 사과, 野도 정부 출범 협조를
# 78 번째 기사
# 통진당 해산 반대 등 功으로 헌재소장 시킨다고 공식화
# 79 번째 기사
# '빚 갚으라'는 촛불 단체들, 文 정부 첫 시험대
# 80 번째 기사
# 靑 특수활동비 축소, 다음은 국회·檢·警이다
# 81 번째 기사
# '비정규직 부담금' 전시 행정 말고 진짜 문제 봐야
# 82 번째 기사
# 집무실에 일자리 상황판, 70년대 풍경 아닌가
# 83 번째 기사
# 이낙연 후보 과거와 다른 총리 되겠다는 결의 보여달라
# 84 번째 기사
# 절차 무시한 人事·업무 지시 더 이상은 없기를
# 85 번째 기사
# 文 '노무현 뛰어넘고 성공한 대통령 되겠다'
# 86 번째 기사
# 수갑 찬 전직 대통령을 봐야 하는 국민의 고통
# 87 번째 기사
# '검찰은 악마'라는 경찰, 국민 눈엔 둘이 다르지 않다
# 88 번째 기사
# 7년간 네 번째 4대강 조사, 풍차를 괴물이라고 또 돌진
# 89 번째 기사
# 우리가 '5·24' 해제하면 천안함 장병들은 누가 죽인 건가
# 90 번째 기사
# 美국적·위장전입, 민주가 野였으면 어떻게 했겠나
# 91 번째 기사
# 새 외교·안보팀은 北核 無경험자들, 北은 또 미사일 도발
# 92 번째 기사
# 김동연 '5년 정권' 아닌 '50년 한국 경제' 보고 가길
# 93 번째 기사
# '촛불 참가했으니 빚 갚으라'고 정부에 요구한 전교조
# 94 번째 기사
# '통진당 해산 반대' 헌재 소장, 국민이 받아들일 수 있나
# 95 번째 기사
# 윤석열 지검장 "사람에게 충성 않는다" 신조 지키라
# 96 번째 기사
# 내년 6월 '제7공화국' 첫발 내디딘다
# 97 번째 기사
# 대통령·검찰 완전 絶緣하고 특수활동비 없애라
# 98 번째 기사
# 새 정부서 처음 들어보는 '경제 역동성'이란 말
# 99 번째 기사
# 눈살을 찌푸리게 하는 몇몇 풍경들
# 100 번째 기사
# '돈 봉투' 검찰 두 핵심에 대한 초유의 감찰
# 101 번째 기사
# 北核 대화에는 진짜가 있고 가짜가 있다
# 102 번째 기사
# 사드만 국회에 넘기는 그 이유를 설명하라
# 103 번째 기사
# 北 도발·美 혼돈 속 열리는 한·미 정상회담
# 104 번째 기사
# 文 정부 '창업 공신'들 처신 신선하다
# 105 번째 기사
# 이른바 '문빠'의 인터넷 홍위병 행태 점입가경
# 106 번째 기사
# 뉴욕 겨냥 北 ICBM 코앞, 文 국민 어떻게 지킬 건가
# 107 번째 기사
# '미세 먼지 줄이기' 국민 부담 는다는 것부터 알려야
# 108 번째 기사
# '규제프리존법' 민주만 반대, 아직 야당인 줄 아나
# 109 번째 기사
# 김정은, 文 대통령을 시험대에 올렸다
# 110 번째 기사
# '비정규직 0' 말처럼 쉽다면 '비정규직 금지법' 왜 못 만드나
# 111 번째 기사
# 전병헌 정무, 30년 만의 分權 개헌에 모든 것 걸어야
# 112 번째 기사
# 국정교과서 내용 무엇이 잘못돼 폐지하나
# 113 번째 기사
# '정윤회 사건 재조사'가 그렇게 화급한 사안인가
# 114 번째 기사
# 美 CIA와 韓 국정원
# 115 번째 기사
# 사면초가 안보 현실 보여준 美·中·日 頂上과 통화
# 116 번째 기사
# '검찰 독립' 취임사 다음 날 검찰 수사 언급한 文 대통령
# 117 번째 기사
# '작은 청와대'라더니 이게 뭔가
# 118 번째 기사
# 文 대통령의 첫날
# 119 번째 기사
# 이낙연 총리 후보, '제청 쇼' 하지 않을 결의 돼 있나
# 120 번째 기사
# 51세 임종석 실장, 작고 낮고 젊은 청와대로
# 121 번째 기사
# 文 대통령, '노무현 2期' 아닌 統合·協治 불가피하다
# 122 번째 기사
# 保守의 대선 패배 이번으로 끝날 것인가
# 123 번째 기사
# 오늘 투표, 분열과 저주 끝내는 날 될 수 있는가
# 124 번째 기사
# 새 정부, 미세 먼지 대책에 숭숭 뚫린 구멍부터 메워라
# 125 번째 기사
# 75세 넘어서도 뭐든 해야 먹고사는 한국 노인들
# 126 번째 기사
# '미세 먼지' 새 정부 최우선 과제 돼야
# 127 번째 기사
# 洪 후보의 친박 핵심 징계 해제
# 128 번째 기사
# 文 후보 "보복 안 한다" 몇 시간 뒤엔 "청산한다"
# 129 번째 기사
# 통합·협치 정신 가져야 새 정부 순조롭게 출발한다
# 130 번째 기사
# 새 대통령 사상 최고 株價 속에 출발하지만
# 131 번째 기사
# 美 새 대북 제재법 전 世界에 확산시켜야
# 132 번째 기사
# 세월호 정치 이용 끝에 벌어진 한심한 소란
# 133 번째 기사
# '中·北 우호조약 수명 다했다' 中 매체 언급 주목해야
# 134 번째 기사
# 美 인종 갈등 닮은 韓 세대 분열, 방치 안 된다
# 135 번째 기사
# 해외 나간 일자리 109만개, 들어온 일자리는 7만개
# 136 번째 기사
# 바른정당 탈당 의원들이 맞는 逆風을 보며
# 137 번째 기사
# '여론조사 공표 금지' 다음 선거 땐 폐지해야
# 138 번째 기사
# 트럼프 매일 對北 발언, 이번엔 "김정은 만나겠다"
# 139 번째 기사
# 바른정당 의원들의 脫黨
# 140 번째 기사
# 대선 후보들 국민통합 위해 나왔나, 분열시키러 나왔나
# 141 번째 기사
# 文 후보 '노무현 비극' 보복하려 집권하는 건가
# 142 번째 기사
# 불길하게 이어지는 한·미 사드 비용 논란
# 143 번째 기사
# 공기업 연봉이 대기업 추월, 비정상 퇴행 국가의 징후
# 144 번째 기사
# 美 안보보좌관이 트럼프 사드 발언 취소
# 145 번째 기사
# 文 측 이제 다 이겼다고 "이×들아" "궤멸시킨다" 하나
# 146 번째 기사
# 코트라 "中·日은 美 통상 공세 선방"
# 147 번째 기사
# 트럼프 대통령 "사드 비용 한국 부담" 발언 취소하라
# 148 번째 기사
# 트럼프 "한·미 FTA 끔찍하다"는데 위기감·전략도 없는 후보들
# 149 번째 기사
# 트럼프 방향 전환 가능성, '北核 동결'쇼에 또 속아선 안 돼
# 150 번째 기사
# 취임 준비 기간 없는 대선, 총리 사전 공개 필요하다
# 151 번째 기사
# 미국은 법인세 내려 일자리 만든다는데
# 152 번째 기사
# 북핵·미사일 방어 장비 배치 놓고 소란 너무 지나치다
# 153 번째 기사
# 상대 후보에게 '내 아랫사람과 토론하라'니
# 154 번째 기사
# '해준다' 공약은 남발, 거기 드는 세금은 축소 발표
# 155 번째 기사
# '북핵 실험 억제'가 목표일 수는 없다
# 156 번째 기사
# 文 후보, 행복해하기 앞서 나라 걱정에 밤잠 설치길
# 157 번째 기사
# 대선 막판에 다시 떠오른 '단일화' 문제
# 158 번째 기사
# "北 인권案에 기권한 게 뭐 잘못이냐"는 진보 진영
# 159 번째 기사
# 국민 부끄럽게 한 '역대 최악급' 대선 토론회
# 160 번째 기사
# 반가운 수출 호조, 일자리 안 늘면 무슨 소용인가
# 161 번째 기사
# 中 '美, 北核시설 타격' 수용 조짐, 對北 최후통첩이다
# 162 번째 기사
# 文, 집권 때 北이 싫다고 하면 안 할 텐가
# 163 번째 기사
# '北에 물어보고 기권' 선거 前에 판명나야 한다
# 164 번째 기사
# 선의의 기부자에 세금 폭탄 막는 '황필상法' 당장 만들라
# 165 번째 기사
# '북=주적, 말 않는 文' '햇볕 계승 여부 얼버무린 安'
# 166 번째 기사
# 전인권·정의당 몰매 공격 文 지지세력이 바로 적폐다
# 167 번째 기사
# 180억 기부자에 훈장 아닌 세금 폭탄 주고 7년 괴롭힌 나라
# 168 번째 기사
# 국민에 해야 할 말은 일절 않고 '준다'고만 하는 후보들
# 169 번째 기사
# 시진핑 "한반도는 中의 일부였다" 이게 中의 對韓 인식
# 170 번째 기사
# 이번엔 '개표 부정' 영화, 역겨운 선거운동
# 171 번째 기사
# 복지 경쟁 大選 몇 번 더 하면 나라 거덜나지 않겠나
# 172 번째 기사
# '적폐' 놓고 오락가락 文, 호남 정서 기대는 安
# 173 번째 기사
# 법원에도 정치 바람 불기 시작한 건가
# 174 번째 기사
# "트럼프를 시험하지 말라"는 美 부통령의 경고
# 175 번째 기사
# '한국 피란민 선별한다'는 아베의 치졸한 언행
# 176 번째 기사
# '최순실' 이후 결정 장애 신드롬, 국민연금뿐인가
# 177 번째 기사
# 美 부통령 訪韓, 中·北에 확실한 메시지 보내야 한다
# 178 번째 기사
# 大選 공식 개막, 안보·경제 위기 맡길 후보 어디 있나
# 179 번째 기사
# 일대 모험이 될 '文, 국립대 공동입학' '安, 5-5-2 학제'
# 180 번째 기사
# 美 超대형 폭탄 실전 첫 사용, 北은 가볍게 보지 말아라
# 181 번째 기사
# 2弱이 2强을 압도했다는 평가를 보며
# 182 번째 기사
# 아동수당, 꼭 이렇게 '선거 선심用'으로 추진해야 하나
# 183 번째 기사
# 대선 후보들 "北 타격 반대" 核 쥔 김정은이 가장 반길 것
# 184 번째 기사
# 文·安 간단한 의혹 대처도 못하며 國政 어떻게 하나
# 185 번째 기사
# 1인당 18분, 5번 TV토론으로 후보 자질 어떻게 알겠나
# 186 번째 기사
# 조기 대선 무방비 상태서 맞은 한반도 정세 중대 고비
# 187 번째 기사
# 세금 걷어 성장하겠다는 文 후보, 일본 실패는 못 봤나
# 188 번째 기사
# 中, 6차 북핵실험시 '원유공급 중단' 이번만은 실행해야
# 189 번째 기사
# 文·安 두 사람 안보 정책 정말 믿을 수 있나
# 190 번째 기사
# 규제프리존法도 '적폐'라는 건가
# 191 번째 기사
# 선제타격보다 美 대북 정책 유턴 더 주목해야
# 192 번째 기사
# "기득권과 대결"이란 文, "편 가르기 끝낸다"는 安
# 193 번째 기사
# 박빙 대선, 이기고 보자는 포퓰리즘 창궐할 수 있다
# 194 번째 기사
# 文·安, '대통령감인가' 의구심 떨치느냐에 달렸다
# 195 번째 기사
# 美·中 '실패한 對北 30년' 또 답습 안 된다
# 196 번째 기사
# 시진핑 앞에서 시리아 폭격한 트럼프
# 197 번째 기사
# 文·安 각종 의혹에 舊態 대응, 한 달만 넘기자는 건가
# 198 번째 기사
# 홍준표·유승민, 먼 길일수록 正道로 가달라
# 199 번째 기사
# 대선 판세 급변, 文·安 민심 제대로 읽으라
# 200 번째 기사
# 유승민 "NATO식 核 공유 추진" 다음 정부 검토할 만하다
# 201 번째 기사
# 對北 '선제 타격' '전격 협상' 둘 다 주시해야
# 202 번째 기사
# 중대한 美·中 회담 '제2 얄타' 안 된다
# 203 번째 기사
# 검증 회피하려는 대선 주자는 후보 자격 없다
# 204 번째 기사
# 한국이 인터넷 은행 꼴찌 된 이유
# 205 번째 기사
# 안철수, '非文'을 뛰어넘는 가치가 뭔가
# 206 번째 기사
# 내부 政爭이 이스라엘과 한국의 차이를 불렀다
# 207 번째 기사
# 국가부채 1400조, 그래도 세금으로 공무원 늘린다니
# 208 번째 기사
# 두 번째 도전 文, 과거 머물며 편 가르면 또 실패할 것
# 209 번째 기사
# 주목해야 할 트럼프 대통령의 兩面 언급
# 210 번째 기사
# 주한 일본 대사 85일 만의 복귀
# 211 번째 기사
# 이번 주 大選 구도 확정, 分權 당장 실천할 대통령을
# 212 번째 기사
# 대통령 비극의 城, '1000명 巨大 청와대'
# 213 번째 기사
# 문 전 대표 아들 문제 대체 뭔가
# 214 번째 기사
# 하야·피살·자살·탄핵·구속의 대통령史 다음 차례는 누군가
# 215 번째 기사
# 보수 최악 위기 속 대선 후보 선출된 홍준표
# 216 번째 기사
# 안철수 浮上이 의미하는 것
# 217 번째 기사
# '統合정부' 누가 집권해도 가져야 할 정신이다
# 218 번째 기사
# 조희연 교육감, 박원순 시장의 분별 잃은 처신
# 219 번째 기사
# 연대·고대가 먼저 체육 특기생制 폐지한다면
# 220 번째 기사
# 중도·보수 단일화, 국민 감동시킬 수 있는가
# 221 번째 기사
# 정부 사업비 써서 정치에 학생 동원한 교수
# 222 번째 기사
# 전쟁도 부모 동의받고 할 건가
# 223 번째 기사
# '미안하다' 한마디 없는 세월호 怪談 유포자들
# 224 번째 기사
# 유승민 바른정당 후보가 헤쳐 나가야 할 길
# 225 번째 기사
# 3만달러 벽에 막힌 나라, 成長 내건 대선 후보도 없어
# 226 번째 기사
# 朴 前 대통령 구속영장 청구
# 227 번째 기사
# 김수남 검찰총장도 거취 고민해야 할 때다
# 228 번째 기사
# 압승 文, 이제 '운동권 정치' 접고 국민 안보 불안 직시해야
# 229 번째 기사
# 세월호와 함께 떠오른 眞實, 괴담 세력은 또 '아니면 말고'
# 230 번째 기사
# 北 6차 핵실험 시 김정은 정권 枯死로 방향 전환해야
# 231 번째 기사
# 美 의회 사드 보복 中 규탄, 韓 국회는 우리 정부 규탄
# 232 번째 기사
# 나라 지키다 순직한 군인들 추모에도 與野가 있나
# 233 번째 기사
# 朴 前 대통령 신병 처리 문제
# 234 번째 기사
# 세월호 3년, '안전 업그레이드'는 없고 政爭만 있었다
# 235 번째 기사
# 민주 이번엔 유출 事故, 이래서 국민 신뢰 얻겠나
# 236 번째 기사
# 5조8000억 또 지원받는 대우조선, 도덕적 해이는 그대로
# 237 번째 기사
# 美가 걱정하기 시작한 韓 차기 정부 對北 정책
# 238 번째 기사
# 安 지사 "文, 사람 질리게 한다"가 주는 의미
# 239 번째 기사
# 일자리 만들기에 묘책이나 지름길은 없다
# 240 번째 기사
# 검찰청 출두 前 대통령 이번이 마지막이어야 한다
# 241 번째 기사
# '되는 게 없는 韓, 안 되는 게 없는 日' 차이는 政治다
# 242 번째 기사
# 美 국무 말처럼 한반도 미래는 예측할 수 없다
# 243 번째 기사
# '공무원 정치 허용' 표 얻으려 불법·위헌 약속까지 하나
# 244 번째 기사
# 백악관까지 번진 '탄핵 댓글 전쟁' 부끄러울 뿐
# 245 번째 기사
# ICBM 쏜다는 北, 美 탓이란 中, 내분에 빠진 韓
# 246 번째 기사
# 野 "성과연봉제 폐지", 이 포퓰리즘이 청소해야 할 적폐
# 247 번째 기사
# 한국만 '세계경제의 봄'에서 소외되나
# 248 번째 기사
# 對北 정책 '트럼프 對 한국 野' 충돌 코스로 가고 있다
# 249 번째 기사
# 싫어하는 국민이 더 많은 대선 주자들
# 250 번째 기사
# 안팎에서 난타당하는 롯데, 무슨 죄 지었다고 괴롭히나
# 251 번째 기사
# '保守 빙하기' 희생만이 얼음 녹일 희망 만들 것
# 252 번째 기사
# 아무리 지지율 1위라지만 너무하는 민주당 사람들
# 253 번째 기사
# "보복은 中에도 피해" 중국 일각의 자성론
# 254 번째 기사
# 실업자·구직포기 185만명, 우리 경제 어디로 가나
# 255 번째 기사
# 黃 총리 불출마, 保守서 오랜만에 보는 상식적 판단
# 256 번째 기사
# 대선 前 국회 개헌안 제시, 2018년 투표가 현실적이다
# 257 번째 기사
# 정부에 손 들고 꼼짝 말라는 점령군 행패 앞으로 어떻겠나
# 258 번째 기사
# 또 한 명의 전직 대통령이 검찰에 출두하는 사태
# 259 번째 기사
# 대선 주자들 '私교육 고통 줄이기' 공약으로 승부를
# 260 번째 기사
# 한·미 FTA를 "賣國"이라던 野와 文, 정말 집권 자격 있나
# 261 번째 기사
# 朴 前대통령, 歷史에 평가 맡기고 市民으로 돌아가길
# 262 번째 기사
# '韓·印尼 비즈니스 서밋' 中 넘어 아세안 거대 市場 보자
# 263 번째 기사
# 朴 前 대통령의 마지막 모습
# 264 번째 기사
# 文 전 대표가 노(No) 할 것, 하지 말아야 할 것
# 265 번째 기사
# 광화문광장 흉물 천막들 이제 걷어낼 때다
# 266 번째 기사
# 분열 대립 멈추고 나라를 생각해야 한다
# 267 번째 기사
# 오늘 시험대 오르는 대한민국, '역사적 승복'으로 위기 끝내자
# 268 번째 기사
# 시진핑 주석, '스트롱맨' 아닌 존경받는 지도자 되길
# 269 번째 기사
# 10일 탄핵 심판 선고, 모두 自重하고 또 自制하자
# 270 번째 기사
# 日 사드 레이더엔 아무 말 않는 中, 한국만 만만한가
# 271 번째 기사
# 트럼프 통상팀 잘못된 인식 어떻게 대처하나
# 272 번째 기사
# 사드 장비 한국 도착, 이제 국내 정쟁 중단을
# 273 번째 기사
# 트럼프 "北 엄청난 대가", 예사롭지 않다
# 274 번째 기사
# 北 이번엔 인질극, 아세안 10개국이 공동 제재를
# 275 번째 기사
# 北은 핵·화학·미사일 3종 도발, 집권유력 野는 '햇볕' 고수
# 276 번째 기사
# 특검, '최순실 국정농단'의 本流 꿰뚫은 수사였나
# 277 번째 기사
# 중국 땅인지 착각게 한 롯데 앞 촛불 시위대
# 278 번째 기사
# 운명의 일주일, '탄핵' '기각' 이후가 더 중요하다
# 279 번째 기사
# '美, 전술核 재배치' 검토한다는데, 우린 누가 챙기나
# 280 번째 기사
# 외국이 시비 걸 때마다 군사정책 국회 비준받을 텐가
# 281 번째 기사
# 中, 對北 송유관 끊어 北核 없애면 사드 자동 해결된다
# 282 번째 기사
# 中 보복 비판 文측 '새 정부도 사드 배치' 선언해야
# 283 번째 기사
# 간병이 부른 부부의 비극, 모두의 문제일 수 있다
# 284 번째 기사
# 중국 의존도 못 줄이면 한국 얕보는 횡포 계속된다
# 285 번째 기사
# 세월호 천막은 합법, 태극기 천막은 불법이라는 朴 시장
# 286 번째 기사
# 이념 교과서 지키려 입학식마저 훼방 놓은 좌파 교육독재
# 287 번째 기사
# 촛불·태극기, 앞으로 열흘만이라도 집회 중단을
# 288 번째 기사
# 中의 저급한 對韓 공세 이겨내야만 한다
# 289 번째 기사
# 北, 화학무기 없다면 금지조약 가입해 사찰받으라
# 290 번째 기사
# 70년 전 '左·右 따로 삼일절'이 지금 재연된다니
# 291 번째 기사
# 역사적 탄핵 심판 첫 평의, '절대 非공개'로 헌재 보호해야
# 292 번째 기사
# 삼성 미래전략실 해체 '권력과 기업' 정상화 계기로
# 293 번째 기사
# 視界 제로 2週, 文부터 "촛불집회 중단" 호소를
# 294 번째 기사
# 마지막까지 핵심 의문에 답하지 않은 朴대통령
# 295 번째 기사
# 롯데 사드 부지 제공, '김관진 특사'로 中 끝까지 설득을
# 296 번째 기사
# 탄핵 찬반으로 두 쪽 난 사회, 꼭 끝을 봐야 하나
# 297 번째 기사
# 文 "쌀과 북 광물 맞교환", 핵·독가스는 눈에 안 보이나
# 298 번째 기사
# 中, 對北 송유관 끊어 김정은 만행 멈추게 하라
# 299 번째 기사
# '시위 참여' '헌재 불복' 정치인들 大選 말고 시민단체 가야
# 300 번째 기사
# 형제 독살에 최악 화학무기 VX 사용한 김정은
# 301 번째 기사
# 기업인들 언제까지 '출국 금지 감옥'에 가둬 놓을 건가
# 302 번째 기사
# 헌재서 벌어진 광경, 파국 예고편일 수 있다
# 303 번째 기사
# 변협·헌정회 "대선 주자들 헌재 결정 승복 천명하라"
# 304 번째 기사
# 北 범죄 싸고돈 중국이 北을 이 지경 만든 것
# 305 번째 기사
# 대통령 측 "아스팔트에 피", 경악할 法治 거부 선동
# 306 번째 기사
# '아웅산' 이어 '김정남' 때도 작전본부였던 北 대사관
# 307 번째 기사
# 우병우, 최순실 사태 최대 책임자 중 하나로 역사에 기록될 것
# 308 번째 기사
# 김정은의 兄 독살 테러도 '있을 수 있다'는 文측 위원장
# 309 번째 기사
# 탄핵 찬반 파괴적 정면충돌 바라볼 수밖에 없다면
# 310 번째 기사
# '정치'와 '지역'에 휘둘린 555조 국민 노후자금
# 311 번째 기사
# "헌재에 맡기자" 촛불 들기를 멈춘 안철수의 소신
# 312 번째 기사
# 외교 관계를 범죄에 이용하는 北을 세계가 단죄해야
# 313 번째 기사
# 문명고 金 교장 같은 분, 백명 천명 나와야 교육이 선다
# 314 번째 기사
# '김정은이 김정남 암살' 확인, 차원 다른 대책 준비할 때
# 315 번째 기사
# 中은 北 석탄 전면 봉쇄, 민주당은 '개성·금강산' 재개
# 316 번째 기사
# 우병우 결국 구속영장 청구, 법원 판단 주목한다
# 317 번째 기사
# 이재용 구속, 뇌물 줬는지 피해자인지 법정서 가려야
# 318 번째 기사
# 70% 對 11%
# 319 번째 기사
# 시민이 침묵하면 反대한민국 교과서 못 막는다
# 320 번째 기사
# 헌재 3월 초 선고 유력, 여야·시위대 정말 자중할 때 왔다
# 321 번째 기사
# 말레이시아, 김정남 시신 인도보다 진상 규명 먼저
# 322 번째 기사
# 재벌개혁 아니라 중소·중견기업 잡는 商法 개정안
# 323 번째 기사
# 野 후보들 이래도 김정은에 달러 주고 사드 반대할 건가
# 324 번째 기사
# 신간회 90년, 통합 운동 선열이 통탄할 후손의 분열
# 325 번째 기사
# 대통령이 도피한 최순실과 차명폰으로 127번 통화
# 326 번째 기사
# 김정남 독침 피살, 김정은 권력 내부에 무슨 일 있나
# 327 번째 기사
# 北 도발 때마다 5000만 국민이 바보 되는 듯하다
# 328 번째 기사
# 특검 결국 이재용 영장 재청구, 의지인가 오기인가
# 329 번째 기사
# 北 신형 미사일 사드만 요격 가능, 대선 주자들 입장 뭔가
# 330 번째 기사
# 여야 '헌재 승복' 합의, 촛불·태극기 세력도 승복 선언해야
# 331 번째 기사
# 자유한국당, 지지율 '0' 가까운 대선 주자가 10여명
# 332 번째 기사
# 시위대 속 대선 주자들, 나라 걱정하나 선거 걱정하나
# 333 번째 기사
# 北 미사일 도발에 즉각 공동성명 낸 美·日 정상
# 334 번째 기사
# 이재용 再소환, 정상 수사인가 먼지떨이 수사인가
# 335 번째 기사
# 나라 걱정한다면 대선 주자들 헌재 압박 시위 불참해야
# 336 번째 기사
# 교과서 연구학교 신청 '0', 무서운 교육계 좌파 독재
# 337 번째 기사
# "정치가 국민 가난하게 만들 法만 만든다"
# 338 번째 기사
# '헌재 결정 승복' 공개 약속 않는 대선 주자 퇴출시켜야
# 339 번째 기사
# AI·구제역 동시 엄습인데 백신 효능도 모르는 농림부
# 340 번째 기사
# 부패 교육 척결한다더니 뇌물 챙긴 진보 교육감
# 341 번째 기사
# 憲裁 협박 세력 심각한 불복종 투쟁 직면할 것
# 342 번째 기사
# 文 캠프 내부에서 나온 '세금으로 일자리' 비판
# 343 번째 기사
# 학교에 '교과서 협박', 깡패와 뭐가 다른가
# 344 번째 기사
# 끝장 TV토론과 무제한 검증 피할 수 없다
# 345 번째 기사
# 창의 교육 대개혁으로 나라 운명 바꾸자
# 346 번째 기사
# 韓은 졸업=실업, 日은 졸업=취업
# 347 번째 기사
# 聯政 고민해야 할 비상 상황이다
# 348 번째 기사
# 朴 대통령 774억 왜 최순실에 맡겼는지 설명할 때 왔다
# 349 번째 기사
# '도덕적 해이' 그대론데 구제역 백신 무슨 소용인가
# 350 번째 기사
# 대선 '野·野 대결' 가능성까지 있다는데
# 351 번째 기사
# 대선주자들 '태극기 집회' 저변의 '안보 걱정' 무시 말라
# 352 번째 기사
# 文·安, 법안은 다 막고 선거 구호는 "4차 산업혁명"
# 353 번째 기사
# 트럼프 시대에도 韓美는 이익 아닌 가치 동맹이어야
# 354 번째 기사
# 反美 본색 드러내는 촛불 주도 세력, 시민이 쫓아내야
# 355 번째 기사
# 한국 해운 산업 몰락 '최순실'보다 더 큰 罪
# 356 번째 기사
# 보수 정치, 아직 바닥 아니다
# 357 번째 기사
# 美 국방장관 첫 방문국이 한국이 된 의미
# 358 번째 기사
# 구조조정커녕 세금으로 부실大 연명시킨 엉터리 행정
# 359 번째 기사
# 반기문 사퇴 이후
# 360 번째 기사
# 좌파 천막촌, 탄핵 반대 천막촌 모두 철거하라
# 361 번째 기사
# 商法 등 개정안, 시한 정해 밀어붙일 사안 아니다
# 362 번째 기사
# 황교안 大選 차출설
# 363 번째 기사
# 國定교과서와 質로 승부할 자신 없으면 도태돼야
# 364 번째 기사
# 최순실, 장차관·수석 이어 大使 임명도 개입했다니
# 365 번째 기사
# 박한철 후임 空席, 내일부터 헌재도 비정상이다
# 366 번째 기사
# 탄핵 贊反 세력 일각 극단 행동, 모두 自重해야
# 367 번째 기사
# 세계 흔드는 트럼피즘, 강 건너 불 아니다
# 368 번째 기사
# '50代 보수'의 도전, 보수의 미래 만들 수 있나
# 369 번째 기사
# 박 대통령 변호인단 '중대 결심' 발언 거둬달라
# 370 번째 기사
# 트럼프 태풍 거셀수록 공세적 FTA로 가자
# 371 번째 기사
# 憲裁, '편파 재판' 빌미 줄 언행에 신중해야
# 372 번째 기사
# 최순실 국정 농락이 '거짓말의 산'이라는 朴 대통령
# 373 번째 기사
# 위험한 대치 국면서 벌어진 '朴 대통령 누드화' 파문
# 374 번째 기사
# 트럼프 TPP 탈퇴, 한·미 FTA도 결국 타깃 될 것
# 375 번째 기사
# 국회 朴 대통령 누드 전시, '野 권력' 오만 度 넘었다
# 376 번째 기사
# 바른정당 '議員 좋은 것' 다 버려 희생·헌신 보여달라
# 377 번째 기사
# 트럼프 희생양 멕시코로 끝날까
# 378 번째 기사
# 文·潘 "선거 횟수 줄이자", 옳은 방향이다
# 379 번째 기사
# 2년 허송 健保 개편, 방향 맞으면 결론 내야
# 380 번째 기사
# 정치권 50代 역할론 주목한다
# 381 번째 기사
# "증오와 분열 집단이 권력 잡았다"
# 382 번째 기사
# 수갑 찬 김기춘·조윤선 모습을 보며
# 383 번째 기사
# 트럼프 취임, '낯선 미국'에 대비돼 있나
# 384 번째 기사
# 그래도 法官이 허약한 우리 法治를 지키고 있다
# 385 번째 기사
# 檢定 필자들 집필 거부, 이참에 검정 교과서도 확 바꾸자
# 386 번째 기사
# 특검, 국정 농단 本流 수사로 돌아가라
# 387 번째 기사
# 무죄 확정 아닌 삼성, 大衆 반감 뿌리 살피길
# 388 번째 기사
# 朴 대통령 왜 차명폰 갖고 있나
# 389 번째 기사
# 군 복무 기간이 선거 도박판 판돈 된 나라
# 390 번째 기사
# 공무원 81만명 늘린다는 文, 현대차 공장은 美로
# 391 번째 기사
# 실망스러운 반기문 귀국 1주일
# 392 번째 기사
# 편 가르기 말자는 文, 본인부터 실천하길
# 393 번째 기사
# 한국 정당名 중 最古는 3년 된 정의당이란 희극
# 394 번째 기사
# 대통령이 수석들 모아놓고 거짓말 모의했다니
# 395 번째 기사
# 특검이 청구한 이재용 구속영장, 법원 판단 주목한다
# 396 번째 기사
# '분노한 神'과 '허약한 법치'
# 397 번째 기사
# 100대 기업까지 일자리 줄이는 고용 빙하기
# 398 번째 기사
# 문 전 대표, 안보만은 국내 정치와 분리해야
# 399 번째 기사
# 단선적 '친일' '매국' 시각으로 국제관계 헤쳐가겠나
# 400 번째 기사
# 고속도로 운전 중 10%를 졸음 참으며 한다니
# 401 번째 기사
# 이재용이라고 봐줘서도, 억지로 옭아매서도 안 돼
# 402 번째 기사
# 민주당, 안보실장 訪美 비난 말고 독려해야 하지 않나
# 403 번째 기사
# 포퓰리즘 정부 가능성 '한국이 세계 넷째'
# 404 번째 기사
# '반기문의 政治 교체' 국민이 지켜볼 것
# 405 번째 기사
# '진영 정치 극복하겠다' 50代 대선 주자들의 시도
# 406 번째 기사
# '박수받으며 떠나는 대통령을 보고 싶다'
# 407 번째 기사
# 이재용 뇌물 혐의 소환, 수사 원칙은 '증거'가 돼야
# 408 번째 기사
# 민주당과 트럼프 대북정책 충돌 안 할 수 있나
# 409 번째 기사
# 국정화·검정 강화 다 안 된다는 교과서 이념 독재
# 410 번째 기사
# 한·중·일 군용기 50여 대 東海 대치, 누가 관심 있나
# 411 번째 기사
# 트럼프는 일자리 전쟁, 우리는 대기업과 전쟁
# 412 번째 기사
# 朴 대통령부터 탄핵 심판 나와 당당하게 입장 밝히라
# 413 번째 기사
# 세계는 4차 산업혁명, 우리는 殺氣 띤 과거 회귀
# 414 번째 기사
# 일본의 '위안부 소녀상' 공세 위험하다
# 415 번째 기사
# 정치 탓 체감 경기 악화, 자칫 '자기실현적' 위기 될 것
# 416 번째 기사
# 사회적 內戰 같은 전운 속 '조기 대선' 시동 건 민주당
# 417 번째 기사
# 대통령 하겠다며 외교 위기에도 일언반구 없나
# 418 번째 기사
# 특검 블랙리스트 확인, 최고 책임자가 누군가
# 419 번째 기사
# 새해 벽두 외교 大亂 조짐, 우린 운동권 논리로 맞서나
# 420 번째 기사
# 중국에도 뒤진 채 맞는 4차 산업혁명 시대
# 421 번째 기사
# 탄핵 심판 의도적 지연은 허용될 수 없다
# 422 번째 기사
# 文 "靑·검찰·국정원 권력 축소" 공약, 큰 방향은 맞다
# 423 번째 기사
# 개헌특위, 최소한 대선 전에 개헌안 합의 도출해야
# 424 번째 기사
# 민주당은 中의 韓國 주권 농락이 남의 일로 보이나
# 425 번째 기사
# 대통령에서 독립된 공수처 설치, 이제 피할 수 없다
# 426 번째 기사
# 탄핵 반대 고교생이 당한 사이버 테러
# 427 번째 기사
# 트럼프·시진핑 '한반도서 승부' 코스로 간다
# 428 번째 기사
# '개헌을 野合으로 몰아붙이자'는 게 文 생각인가
# 429 번째 기사
# 국정원이 왜 삼성 합병 문제까지 끼어들었나
# 430 번째 기사
# 中이 韓 군사 정책 바꾸는 선례 만들면 재앙 온다
# 431 번째 기사
# 이정현 탈당, 잘못된 일에는 책임지는 게 도리
# 432 번째 기사
# 정유라, 스스로 들어와 조사받는 게 낫다
# 433 번째 기사
# 대한민국을 '안 되는 나라'에서 다시 '되는 나라'로
# 434 번째 기사
# "엮지 말라" 전면 부인 나선 朴 대통령
# 435 번째 기사
# 한국 경제史에서 지워버리고 싶은 2016년
# 436 번째 기사
# 기로에 선 새누리당
# 437 번째 기사
# 동해와 서해 너머의 불길한 조짐들
# 438 번째 기사
# 역사적 개헌특위 출범, 統治 끝내고 協治 열어달라
# 439 번째 기사
# 국립외교원 "내년은 초(超)불확실성의 시대"
# 440 번째 기사
# 외국인에 5배 바가지 택시, 아직 갈 길이 멀다
